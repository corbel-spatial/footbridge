# %% [markdown]
# # DuckDB and Ibis

# %%
import os

import duckdb
import sedonadb
import footbridge as ft

# large dataset of US National Highway System roads, one feature class
# https://hepgis-usdot.hub.arcgis.com/datasets/dce9f09392eb474c8ad8e6a78416279b_0
gdb_path = os.path.abspath("NHS.gdb")
fc = ft.GeoDatabase(gdb_path)[0]
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/worker/footbridge/.pixi/envs/dev/share/proj failed

# %% [markdown]
# ## DuckDB

# %%
fc_wkt = fc.gdf.to_wkt()
duckdb.sql("""
           SELECT ROUTEID, MILES, geometry
           FROM fc_wkt
           WHERE ROUTEID='50' AND MILES < 0.25
           """).to_df()
# Out:
#   ROUTEID     MILES  \
# 0      50  0.249906
# 1      50  0.149902
# 2      50  0.010009
# 3      50  0.059970
# 4      50  0.101489
# 5      50  0.011913
#
#                                                                                                                                                                                                    geometry
# 0  MULTILINESTRING ((-159.444763 21.962309, -159.44503 21.962345, -159.445402 21.962382, -159.445806 21.962407, -159.44618 21.962414, -159.446741 21.962397, -159.447361 21.962339, -159.448635 21.962172))
# 1                                                                                            MULTILINESTRING ((-159.379746 21.972255, -159.380151 21.972109, -159.380652 21.971943, -159.381948 21.971529))
# 2                                                                                            MULTILINESTRING ((-159.379603 21.972313, -159.379681 21.972281, -159.379742 21.972256, -159.379746 21.972255))
# 3                                                                                                                    MULTILINESTRING ((-159.370689 21.976136, -159.370876 21.976116, -159.37162 21.976062))
# 4                                                                                                                                            MULTILINESTRING ((-90.998261 38.445815, -90.997831 38.444383))
# 5                                                                                                                                            MULTILINESTRING ((-90.986489 38.414795, -90.986433 38.414628))

# %% [markdown]
# ## SedonaDB

# %%
# TODO
